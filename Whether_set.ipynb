# %%
import pandas as pd

# %%
data = pd.read_csv('weather.csv')

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
data.shape
# Out:
# (366, 22)

# %%
del data['Cloud9am']

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0             30.0         SW         NW           6.0  ...           68
# ...

# %%
data=data.drop(columns=['Cloud3pm'])

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0             30.0         SW         NW           6.0            20
# ...

# %%
data[['MinTemp','MaxTemp']]
# Out:
#      MinTemp  MaxTemp
# 0        8.0     24.3
# 1       14.0     26.9
# 2       13.7     23.4
# 3       13.3     15.5
# 4        7.6     16.1
# ..       ...      ...
# 361      9.0     30.7
# 362      7.1     28.4
# 363     12.5     19.9
# 364     12.5     26.9
# 365     12.3     30.2
#
# [366 rows x 2 columns]

# %%
data.count
# Out:
# <bound method DataFrame.count of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %%
data.head(40)
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0       8.0     24.3       0.0          3.4       6.3          NW
# 1      14.0     26.9       3.6          4.4       9.7         ENE
# 2      13.7     23.4       3.6          5.8       3.3          NW
# 3      13.3     15.5      39.8          7.2       9.1          NW
# 4       7.6     16.1       2.8          5.6      10.6         SSE
# 5       6.2     16.9       0.0          5.8       8.2          SE
# 6       6.1     18.2       0.2          4.2       8.4          SE
# 7       8.3     17.0       0.0          5.6       4.6           E
# 8       8.8     19.5       0.0          4.0       4.1           S
# 9       8.4     22.8      16.2          5.4       7.7           E
# 10      9.1     25.2       0.0          4.2      11.9           N
# 11      8.5     27.3       0.2          7.2      12.5           E
# 12     10.1     27.9       0.0          7.2      13.0         WNW
# ...

# %%
data.MaxTemp=data.MaxTemp.fillna(data.MaxTemp.mean())

# %%
data.head(40)
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0       8.0     24.3       0.0          3.4       6.3          NW
# 1      14.0     26.9       3.6          4.4       9.7         ENE
# 2      13.7     23.4       3.6          5.8       3.3          NW
# 3      13.3     15.5      39.8          7.2       9.1          NW
# 4       7.6     16.1       2.8          5.6      10.6         SSE
# 5       6.2     16.9       0.0          5.8       8.2          SE
# 6       6.1     18.2       0.2          4.2       8.4          SE
# 7       8.3     17.0       0.0          5.6       4.6           E
# 8       8.8     19.5       0.0          4.0       4.1           S
# 9       8.4     22.8      16.2          5.4       7.7           E
# 10      9.1     25.2       0.0          4.2      11.9           N
# 11      8.5     27.3       0.2          7.2      12.5           E
# 12     10.1     27.9       0.0          7.2      13.0         WNW
# ...

# %%
data['MaxTemp']>45
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: MaxTemp, Length: 366, dtype: bool

# %%
condition=data['MaxTemp']>22)&(data['MinTemp']<10)
filter=data[condition]
filter
# Out:
#   Cell In[34], line 1
#     condition=data['MaxTemp']>22)&(data['MinTemp']<10)
#                                 ^
# SyntaxError: unmatched ')'

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %%
import matplotlib.pyplot as plt
x = range(119040)
y1=data['MaxTemp'][:20]

y2=data['MinTemp'][:20]
plt.plot(x,y1)
plt.plot(x,y2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 5
#       3 y1=data['MaxTemp']
#       4 y2=data['MinTemp']
# ----> 5 plt.plot(x,y1)
#       6 plt.plot(x,y2)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...
